# %% [markdown]
# # Import

# %%
# !pip install simpletransformers
# Out:
# ...
#      |████████████████████████████████| 248 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 13.9 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 52.4 MB/s
# ...
#      |████████████████████████████████| 9.9 MB 58.5 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 76.6 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 71.8 MB/s
# ...
#      |████████████████████████████████| 325 kB 84.3 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.3 MB/s
# ...
#      |████████████████████████████████| 895 kB 82.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 59.1 MB/s
# ...
#      |████████████████████████████████| 144 kB 79.8 MB/s
# ...
#      |████████████████████████████████| 181 kB 73.1 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.3 MB/s
# ...
#      |████████████████████████████████| 212 kB 67.4 MB/s
# ...
#      |████████████████████████████████| 134 kB 80.8 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 84.3 MB/s
# ...

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import pandas as pd
import logging
from matplotlib import pyplot as plt

logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# %%
from scipy.special import softmax
from google.colab import files

# %% [markdown]
# #Data preparation

# %%
train_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/project/4192/Data/DirectCompare/train_df.csv")

train_df = train_df[['selftext','Expert-label']]
train_df
# Out:
#                                                selftext  Expert-label
# 0     I posted this on Piazza but thought I might as...           1.0
# 1     Hi i’ve applied for arts from Vancouver,BC as ...           0.0
# 2     i'm an international student and i've been tak...           1.0
# 3     i'm an international student and the midterm w...           1.0
# 4     they think i wouldnt be able to handle the str...           0.0
# ...                                                 ...           ...
# 997   My boyfriend is Canadian and I’m American. Obv...           0.0
# 998   Do you need to be vaccinated to travel domesti...           0.0
# 999   Hello, are there any International students he...           1.0
# 1000  Will you guys take a leave of absence? Or are ...           0.0
# 1001  I posted this on Piazza but thought I might as...           1.0
#
# [1002 rows x 2 columns]

# %%
test_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/project/4192/draft/Iteration/simualte_hrir/Iteration2/bert-base/b_b_i2.csv")

test_df = test_df[['selftext']]
test_df
# Out:
#                                               selftext
# 0    Hello, are there any International students he...
# 1    Sorry if this is asked a lot, when will border...
# 2    Hi everyone I'm wondering if there's any chanc...
# 3    For international students in Canada would our...
# 4    I am an international student and currently I’...
# ..                                                 ...
# 195  I’m an international student considering livin...
# 196  With the recent announcement by the government...
# 197                 What about international students?
# 198   https://twitter.com/Olufemiloye/status/138853...
# 199  I have paid my tuition fees through wire trans...
#
# [200 rows x 1 columns]

# %%
test_data = test_df['selftext'].values.tolist()

# %% [markdown]
# #Model

# %%
model_args = ClassificationArgs(train_batch_size=4, gradient_accumulation_steps=16, learning_rate=3e-5, num_train_epochs= 3, max_seq_length= 512, overwrite_output_dir= True)

# %% [markdown]
# ##roberta-base

# %%
model_bt = ClassificationModel('roberta', 'roberta-base',  args = model_args, use_cuda = True)
model_bt.train_model(train_df)
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.bias', 'roberta.pooler.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# ##deberta-base

# %%
model_db = ClassificationModel('deberta', 'microsoft/deberta-base',  args = model_args, use_cuda=True)
model_db.train_model(train_df)
# Out:
# Downloading:   0%|          | 0.00/474 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/533M [00:00<?, ?B/s]
# Some weights of the model checkpoint at microsoft/deberta-base were not used when initializing DebertaForSequenceClassification: ['lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# #Validate

# %%
result_bt,proba_bt = model_bt.predict(test_data)
probabilities = softmax(proba_bt, axis=1)
proba_bt_df=pd.DataFrame(probabilities)
proba_bt_df.columns = ["remove","Expert-label"]
proba_bt_df = proba_bt_df["Expert-label"]
proba_bt_df
# Out:
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]
# 0      0.548228
# 1      0.521934
# 2      0.498001
# 3      0.524905
# 4      0.532486
#          ...
# 195    0.534981
# 196    0.546299
# 197    0.511865
# 198    0.477846
# 199    0.478061
# Name: Expert-label, Length: 200, dtype: float64

# %%
result_db,proba_db = model_db.predict(test_data)
probabilities = softmax(proba_db, axis=1)
proba_db_df=pd.DataFrame(probabilities)
proba_db_df.columns = ["remove","Expert-label"]
proba_db_df = proba_db_df["Expert-label"]
proba_db_df
# Out:
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]
# 0      0.484279
# 1      0.483334
# 2      0.487258
# 3      0.490769
# 4      0.491616
#          ...
# 195    0.490045
# 196    0.486867
# 197    0.486741
# 198    0.440710
# 199    0.479606
# Name: Expert-label, Length: 200, dtype: float64

# %%
val_df=proba_bt_df+proba_db_df
val_df
# Out:
# 0      1.032507
# 1      1.005268
# 2      0.985259
# 3      1.015674
# 4      1.024102
#          ...
# 195    1.025026
# 196    1.033167
# 197    0.998607
# 198    0.918556
# 199    0.957668
# Name: Expert-label, Length: 200, dtype: float64

# %%
val_df=val_df.to_frame()
val_df
# Out:
#      Expert-label
# 0        1.032507
# 1        1.005268
# 2        0.985259
# 3        1.015674
# 4        1.024102
# ..            ...
# 195      1.025026
# 196      1.033167
# 197      0.998607
# 198      0.918556
# 199      0.957668
#
# [200 rows x 1 columns]

# %%
val_df.loc[val_df['Expert-label'] < 0.9] = 0
val_df.loc[val_df['Expert-label'] >= 0.9] = 1
val_df
# Out:
#      Expert-label
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# ..            ...
# 195           1.0
# 196           1.0
# 197           1.0
# 198           1.0
# 199           1.0
#
# [200 rows x 1 columns]

# %%
save_df = pd.concat([test_df,val_df],axis=1)
save_df.head(200)
# Out:
#                                               selftext  Expert-label
# 0    Hello, are there any International students he...           1.0
# 1    Sorry if this is asked a lot, when will border...           1.0
# 2    Hi everyone I'm wondering if there's any chanc...           1.0
# 3    For international students in Canada would our...           1.0
# 4    I am an international student and currently I’...           1.0
# ..                                                 ...           ...
# 195  I’m an international student considering livin...           1.0
# 196  With the recent announcement by the government...           1.0
# 197                 What about international students?           1.0
# 198   https://twitter.com/Olufemiloye/status/138853...           1.0
# 199  I have paid my tuition fees through wire trans...           1.0
#
# [200 rows x 2 columns]

# %%
#Saving to drive

save_df.to_csv('b_b_val_i2.csv')
files.download('b_b_val_i2.csv')
