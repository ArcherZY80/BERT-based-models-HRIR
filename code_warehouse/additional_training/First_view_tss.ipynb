# %% [markdown]
# # Import

# %%
# !pip install simpletransformers

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import pandas as pd
import logging
import sklearn


logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# %%
# !/opt/bin/nvidia-smi
# Out:
# Wed Dec 29 18:27:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # read dataset

# %%
from sklearn.model_selection import train_test_split
train_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/project/4192/Data/DirectCompare/train_df.csv")

X = train_df[['selftext']]
y = train_df[['Expert-label']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
train_df = pd.concat([X_train, y_train], axis=1)
eval_df = pd.concat([X_test, y_test], axis=1)

# %%
y_test.value_counts()
# Out:
# Expert-label
# 0.0             106
# 1.0              95
# dtype: int64

# %% [markdown]
# # **models**

# %%
model_args = ClassificationArgs(train_batch_size=2, gradient_accumulation_steps=16, learning_rate=3e-5, num_train_epochs= 3, max_seq_length= 512, overwrite_output_dir= True)

# %%
model_args_6 = ClassificationArgs(train_batch_size=2, gradient_accumulation_steps=16, learning_rate=3e-5, num_train_epochs= 6, max_seq_length= 512, overwrite_output_dir= True)

# %%
model_args_9 = ClassificationArgs(train_batch_size=2, gradient_accumulation_steps=16, learning_rate=3e-5, num_train_epochs= 9, max_seq_length= 512, overwrite_output_dir= True)

# %% [markdown]
# ##Roberta-base

# %% [markdown]
# ###epoch=3

# %%
model = ClassificationModel('roberta', 'roberta-base',  args = model_args, use_cuda = True)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'roberta.pooler.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_roberta_512_2_2
# ...
# Running Epoch 2 of 3:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of roberta model complete. Saved to outputs/.
# (75, 0.6104659144083658)

# %% [markdown]
# ###epoch=6

# %%
model_6 = ClassificationModel('roberta', 'roberta-base',  args = model_args_6, use_cuda = True)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_6.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_roberta_512_2_2
# ...
# Running Epoch 5 of 6:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of roberta model complete. Saved to outputs/.
# (150, 0.5365120553970337)

# %% [markdown]
# ###epoch=9

# %%
model_9 = ClassificationModel('roberta', 'roberta-base',  args = model_args_9, use_cuda = True)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_9.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_roberta_512_2_2
# ...
# Running Epoch 8 of 9:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of roberta model complete. Saved to outputs/.
# (225, 0.28192864179611205)

# %% [markdown]
# ##Roberta-large

# %% [markdown]
# ###epoch=3

# %%
model_rbal = ClassificationModel('roberta', 'roberta-large',  args = model_args, use_cuda = True)
# Out:
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_rbal.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_roberta_512_2_2
# ...
# Running Epoch 0 of 3:   0%|          | 0/401 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ###epoch=6

# %%
model_rbal_6 = ClassificationModel('roberta', 'roberta-large',  args = model_args_6, use_cuda = True)
# Out:
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_rbal_6.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     732             try:
# --> 733                 item = self._items.popleft()
#     734             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# ...

# %% [markdown]
# ###epoch=9

# %%
model_rbal_9 = ClassificationModel('roberta', 'roberta-large',  args = model_args_9, use_cuda = True)

# %%
model_rbal_9.train_model(train_df)

# %% [markdown]
# ##BERT

# %% [markdown]
# ###epoch=3

# %%
model_bt = ClassificationModel('bert', 'bert-base-uncased',  args = model_args, use_cuda=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_bt.train_model(train_df)
# Out:
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_512_2_2
# ...
# Running Epoch 2 of 3:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# (75, 0.618910878499349)

# %% [markdown]
# ###epoch=6

# %%
model_bt_6 = ClassificationModel('bert', 'bert-base-uncased',  args = model_args_6, use_cuda=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_bt_6.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_512_2_2
# ...
# Running Epoch 5 of 6:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# (150, 0.42323898315429687)

# %% [markdown]
# ###epoch=9

# %%
model_bt_9 = ClassificationModel('bert', 'bert-base-uncased',  args = model_args_9, use_cuda=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_bt_9.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_512_2_2
# ...
# Running Epoch 8 of 9:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# (225, 0.2568752238485548)

# %% [markdown]
# ##BERT-cased

# %% [markdown]
# ###epoch=3

# %%
model_btc = ClassificationModel('bert', 'bert-base-cased',  args = model_args, use_cuda=True)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_btc.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_512_2_2
# ...
# Running Epoch 2 of 3:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# (75, 0.5788637161254883)

# %% [markdown]
# ###epoch=6

# %%
model_btc_6 = ClassificationModel('bert', 'bert-base-cased',  args = model_args_6, use_cuda=True)
# Out:
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/416M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
model_btc_6.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_512_2_2
# ...
# Running Epoch 5 of 6:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# (150, 0.40311432361602784)

# %% [markdown]
# ###epoch=9

# %%
model_btc_9 = ClassificationModel('bert', 'bert-base-cased',  args = model_args_9, use_cuda=True)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_btc_9.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_512_2_2
# ...
# Running Epoch 8 of 9:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# (225, 0.29825200610690644)

# %% [markdown]
# ##BERT-large

# %% [markdown]
# ###epoch=3

# %%
model_btl = ClassificationModel('bert', 'bert-large-uncased',  args = model_args, use_cuda=True)
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_btl.train_model(train_df)
# Out:
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_512_2_2
# ...
# Running Epoch 2 of 3:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# (75, 0.6618190765380859)

# %% [markdown]
# ###epoch=6

# %%
model_btl_6 = ClassificationModel('bert', 'bert-large-uncased',  args = model_args_6, use_cuda=True)
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_btl_6.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_512_2_2
# ...
# Running Epoch 5 of 6:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# (150, 0.33190375645955406)

# %% [markdown]
# ###epoch=9

# %%
model_btl_9 = ClassificationModel('bert', 'bert-large-uncased',  args = model_args_9, use_cuda=True)
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_btl_9.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_512_2_2
# ...
# Running Epoch 8 of 9:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# (225, 0.360382913351059)

# %% [markdown]
# ##BERT-large-cased

# %% [markdown]
# ###epoch=3

# %%
model_btlc = ClassificationModel('bert', 'bert-large-cased',  args = model_args, use_cuda=True)
# Out:
# Some weights of the model checkpoint at bert-large-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_btlc.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_512_2_2
# ...
# Running Epoch 2 of 3:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# (75, 0.5943808237711589)

# %% [markdown]
# ###epoch=6

# %%
model_btlc_6 = ClassificationModel('bert', 'bert-large-cased',  args = model_args_6, use_cuda=True)
# Out:
# Downloading:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.25G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
model_btlc_6.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_512_2_2
# ...
# Running Epoch 5 of 6:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# (150, 0.6054923629760742)

# %% [markdown]
# ###epoch=9

# %%
model_btlc_9 = ClassificationModel('bert', 'bert-large-cased',  args = model_args_9, use_cuda=True)
# Out:
# Some weights of the model checkpoint at bert-large-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_btlc_9.train_model(train_df)
# Out:
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_512_2_2
# ...
# Running Epoch 8 of 9:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# (225, 0.2583859758906894)

# %% [markdown]
# ##ALBERT

# %% [markdown]
# ###epoch=3

# %%
model_abl = ClassificationModel('albert', 'albert-large-v2',  args = model_args, use_cuda=True)
# Out:
# Some weights of the model checkpoint at albert-large-v2 were not used when initializing AlbertForSequenceClassification: ['predictions.dense.weight', 'predictions.decoder.weight', 'predictions.decoder.bias', 'predictions.dense.bias', 'predictions.LayerNorm.bias', 'predictions.LayerNorm.weight', 'predictions.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_abl.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_albert_512_2_2
# ...
# Running Epoch 2 of 3:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of albert model complete. Saved to outputs/.
# (75, 0.6802127583821614)

# %% [markdown]
# ###epoch=6

# %%
model_abl_6 = ClassificationModel('albert', 'albert-large-v2',  args = model_args_6, use_cuda=True)
# Out:
# Some weights of the model checkpoint at albert-large-v2 were not used when initializing AlbertForSequenceClassification: ['predictions.bias', 'predictions.LayerNorm.bias', 'predictions.dense.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.decoder.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_abl_6.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_albert_512_2_2
# ...
# Running Epoch 5 of 6:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of albert model complete. Saved to outputs/.
# (150, 0.7089231363932291)

# %% [markdown]
# ###epoch=9

# %%
model_abl_9 = ClassificationModel('albert', 'albert-large-v2',  args = model_args_9, use_cuda=True)
# Out:
# Some weights of the model checkpoint at albert-large-v2 were not used when initializing AlbertForSequenceClassification: ['predictions.bias', 'predictions.LayerNorm.bias', 'predictions.dense.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.decoder.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_abl_9.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_albert_512_2_2
# ...
# Running Epoch 8 of 9:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of albert model complete. Saved to outputs/.
# (225, 0.40209628846910267)

# %% [markdown]
# ##ALBERT-xxl

# %% [markdown]
# ###epoch=3

# %%
model_abxxl = ClassificationModel('albert', 'albert-xxlarge-v2',  args = model_args, use_cuda=True)
# Out:
# Some weights of the model checkpoint at albert-xxlarge-v2 were not used when initializing AlbertForSequenceClassification: ['predictions.LayerNorm.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias', 'predictions.decoder.bias', 'predictions.dense.weight', 'predictions.dense.bias', 'predictions.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_abxxl.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_albert_512_2_2
# ...
# Running Epoch 0 of 3:   0%|          | 0/401 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ###epoch=6

# %%
model_abxxl_6 = ClassificationModel('albert', 'albert-xxlarge-v2',  args = model_args_6, use_cuda=True)
# Out:
# Some weights of the model checkpoint at albert-xxlarge-v2 were not used when initializing AlbertForSequenceClassification: ['predictions.decoder.bias', 'predictions.dense.bias', 'predictions.bias', 'predictions.LayerNorm.bias', 'predictions.dense.weight', 'predictions.LayerNorm.weight', 'predictions.decoder.weight']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_abxxl_6.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_albert_512_2_2
# ...
# Running Epoch 0 of 6:   0%|          | 0/401 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ###epoch=9

# %%
model_abxxl_9 = ClassificationModel('albert', 'albert-xxlarge-v2',  args = model_args_9, use_cuda=True)
# Out:
# Downloading:   0%|          | 0.00/710 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/851M [00:00<?, ?B/s]
# Some weights of the model checkpoint at albert-xxlarge-v2 were not used when initializing AlbertForSequenceClassification: ['predictions.LayerNorm.weight', 'predictions.LayerNorm.bias', 'predictions.dense.bias', 'predictions.decoder.weight', 'predictions.decoder.bias', 'predictions.dense.weight', 'predictions.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_abxxl_9.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_albert_512_2_2
# ...
# Running Epoch 0 of 9:   0%|          | 0/401 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ##deberta_base

# %% [markdown]
# ###epoch=3

# %%
model_dbb = ClassificationModel('deberta', 'microsoft/deberta-base',  args = model_args, use_cuda=True)
# Out:
# Some weights of the model checkpoint at microsoft/deberta-base were not used when initializing DebertaForSequenceClassification: ['lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.weight', 'config', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.bias']
# - This IS expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_dbb.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_deberta_512_2_2
# ...
# Running Epoch 2 of 3:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of deberta model complete. Saved to outputs/.
# (75, 0.6746521459768215)

# %% [markdown]
# ###epoch=6

# %%
model_dbb_6 = ClassificationModel('deberta', 'microsoft/deberta-base',  args = model_args_6, use_cuda=True)
# Out:
# Some weights of the model checkpoint at microsoft/deberta-base were not used when initializing DebertaForSequenceClassification: ['lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.LayerNorm.bias', 'config', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_dbb_6.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_deberta_512_2_2
# ...
# Running Epoch 5 of 6:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of deberta model complete. Saved to outputs/.
# (150, 0.5209896574479839)

# %% [markdown]
# ###epoch=9

# %%
model_dbb_9 = ClassificationModel('deberta', 'microsoft/deberta-base',  args = model_args_9, use_cuda=True)
# Out:
# Some weights of the model checkpoint at microsoft/deberta-base were not used when initializing DebertaForSequenceClassification: ['lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.LayerNorm.bias', 'config', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.weight']
# - This IS expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_dbb_9.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_deberta_512_2_2
# ...
# Running Epoch 8 of 9:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of deberta model complete. Saved to outputs/.
# (225, 0.30787835379946044)

# %% [markdown]
# ##deberta_large

# %% [markdown]
# ###epoch=3

# %%
model_dbl_1 = ClassificationModel('deberta', 'microsoft/deberta-large',  args = model_args, use_cuda=True)
# Out:
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaForSequenceClassification: ['lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.weight', 'lm_predictions.lm_head.dense.bias', 'config', 'lm_predictions.lm_head.bias', 'lm_predictions.lm_head.LayerNorm.bias']
# - This IS expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_dbl_1.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_deberta_512_2_2
# ...
# Running Epoch 2 of 3:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of deberta model complete. Saved to outputs/.
# (75, 0.6642843898106366)

# %% [markdown]
# ###epoch=6

# %%
model_dbl_1_6 = ClassificationModel('deberta', 'microsoft/deberta-large',  args = model_args_6, use_cuda=True)
# Out:
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaForSequenceClassification: ['lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.weight', 'lm_predictions.lm_head.LayerNorm.bias', 'config', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.bias']
# - This IS expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_dbl_1_6.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_deberta_512_2_2
# ...
# Running Epoch 5 of 6:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of deberta model complete. Saved to outputs/.
# (150, 0.3184222263073025)

# %% [markdown]
# ###epoch=9

# %%
model_dbl_1_9 = ClassificationModel('deberta', 'microsoft/deberta-large',  args = model_args_9, use_cuda=True)
# Out:
# Some weights of the model checkpoint at microsoft/deberta-large were not used when initializing DebertaForSequenceClassification: ['lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.weight', 'lm_predictions.lm_head.LayerNorm.bias', 'config', 'lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.bias']
# - This IS expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model_dbl_1_9.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/801 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_deberta_512_2_2
# ...
# Running Epoch 8 of 9:   0%|          | 0/401 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of deberta model complete. Saved to outputs/.
# (225, 0.46222362956957014)

# %% [markdown]
# # Outputs

# %% [markdown]
# ##Roberta

# %% [markdown]
# ###epoch=3

# %%
result, model_outputs, wrong_predictions = model.eval_model(eval_df)
result
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_deberta_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.38983484654494927, 'tp': 61, 'tn': 79, 'fp': 27, 'fn': 34, 'auroc': 0.7561569016881828, 'auprc': 0.7600177398028681, 'eval_loss': 0.5844933436467097}
# {'mcc': 0.38983484654494927,
#  'tp': 61,
#  'tn': 79,
#  'fp': 27,
#  'fn': 34,
# ...

# %%
prec = 61/(61+27)
reca = 61/95
print("Precision is " + str(prec) +" ,recall rate is " + str(reca))
# Out:
# Precision is 0.6931818181818182 ,recall rate is 0.6421052631578947

# %% [markdown]
# ###epoch=6

# %%
result_6, model_6_outputs, wrong_predictions_6 = model_6.eval_model(eval_df)
result_6
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.45613077223773796, 'tp': 77, 'tn': 68, 'fp': 38, 'fn': 18, 'auroc': 0.7785998013902681, 'auprc': 0.7444536641377109, 'eval_loss': 0.6652627358069787}
# {'auprc': 0.7444536641377109,
#  'auroc': 0.7785998013902681,
#  'eval_loss': 0.6652627358069787,
# ...

# %% [markdown]
# ###epoch=9

# %%
result_9, model_9_outputs, wrong_predictions_9 = model_9.eval_model(eval_df)
result_9
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.52241224484289, 'tp': 73, 'tn': 80, 'fp': 26, 'fn': 22, 'auroc': 0.8322244289970209, 'auprc': 0.7526968935029811, 'eval_loss': 1.0126215402896588}
# {'auprc': 0.7526968935029811,
#  'auroc': 0.8322244289970209,
#  'eval_loss': 1.0126215402896588,
#  'fn': 22,
# ...

# %% [markdown]
# ##Roberta-large

# %% [markdown]
# ###epoch=3

# %%
result_rbal, model_rbal_outputs, wrong_predictions_rbal = model_rbal.eval_model(eval_df)
result_rbal
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.5645709216277424, 'tp': 77, 'tn': 80, 'fp': 26, 'fn': 18, 'auroc': 0.8363455809334658, 'auprc': 0.8073266161582184, 'eval_loss': 0.5406973178570087}
# {'mcc': 0.5645709216277424,
#  'tp': 77,
#  'tn': 80,
#  'fp': 26,
#  'fn': 18,
#  'auroc': 0.8363455809334658,
# ...

# %%
prec = 77/(77+26)
reca = 77/95
print("Precision is " + str(prec) +" ,recall rate is " + str(reca))
# Out:
# Precision is 0.7475728155339806 ,recall rate is 0.8105263157894737

# %% [markdown]
# ###epoch=6

# %%
result_rbal_6, model_rbal_6_outputs, wrong_predictions_rbal_6 = model_rbal_6.eval_model(eval_df)
result_rbal_6

# %% [markdown]
# ###epoch=9

# %%
result_rbal_9, model_rbal_9_outputs, wrong_predictions_rbal_9 = model_rbal_9.eval_model(eval_df)
result_rbal_9
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.5062035362822956, 'tp': 75, 'tn': 76, 'fp': 30, 'fn': 20, 'auroc': 0.8385302879841111, 'auprc': 0.80602680076999, 'eval_loss': 1.1828321436276803}
# {'mcc': 0.5062035362822956,
#  'tp': 75,
#  'tn': 76,
#  'fp': 30,
#  'fn': 20,
#  'auroc': 0.8385302879841111,
# ...

# %% [markdown]
# ##BERT

# %% [markdown]
# ###epoch=3

# %%
result_bt, model_bt_outputs, wrong_predictions_bt = model_bt.eval_model(eval_df)
result_bt
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_deberta_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.30010094131169573, 'tp': 58, 'tn': 73, 'fp': 33, 'fn': 37, 'auroc': 0.702780536246276, 'auprc': 0.6228722616339979, 'eval_loss': 0.6188084528996394}
# {'mcc': 0.30010094131169573,
#  'tp': 58,
#  'tn': 73,
#  'fp': 33,
#  'fn': 37,
# ...

# %%
prec = 58/(58+33)
reca = 58/95
print("Precision is " + str(prec) +" ,recall rate is " + str(reca))
# Out:
# Precision is 0.6373626373626373 ,recall rate is 0.6105263157894737

# %% [markdown]
# ###epoch=6

# %%
result_bt_6, model_bt_6_outputs, wrong_predictions_bt_6 = model_bt_6.eval_model(eval_df)
result_bt_6
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.5154283233577986, 'tp': 75, 'tn': 77, 'fp': 29, 'fn': 20, 'auroc': 0.8147964250248263, 'auprc': 0.7761832744923456, 'eval_loss': 0.5679416656494141}
# {'mcc': 0.5154283233577986,
#  'tp': 75,
#  'tn': 77,
#  'fp': 29,
#  'fn': 20,
#  'auroc': 0.8147964250248263,
# ...

# %% [markdown]
# ###epoch=9

# %%
result_bt_9, model_bt_9_outputs, wrong_predictions_bt_9 = model_bt_9.eval_model(eval_df)
result_bt_9
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.530313289963796, 'tp': 69, 'tn': 85, 'fp': 21, 'fn': 26, 'auroc': 0.8319265143992055, 'auprc': 0.8143106830043753, 'eval_loss': 0.8378788416202252}
# {'mcc': 0.530313289963796,
#  'tp': 69,
#  'tn': 85,
#  'fp': 21,
#  'fn': 26,
#  'auroc': 0.8319265143992055,
# ...

# %% [markdown]
# ##BERT-cased

# %% [markdown]
# ###epoch=3

# %%
result_btc, model_btc_outputs, wrong_predictions_btc = model_btc.eval_model(eval_df)
result_btc
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.27486087615292515, 'tp': 68, 'tn': 59, 'fp': 47, 'fn': 27, 'auroc': 0.7105263157894737, 'auprc': 0.6681396347199684, 'eval_loss': 0.613943833571214}
# {'auprc': 0.6681396347199684,
#  'auroc': 0.7105263157894737,
#  'eval_loss': 0.613943833571214,
#  'fn': 27,
# ...

# %% [markdown]
# ###epoch=6

# %%
result_btc_6, model_btc_6_outputs, wrong_predictions_btc_6 = model_btc_6.eval_model(eval_df)
result_btc_6
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.38288414528063747, 'tp': 66, 'tn': 73, 'fp': 33, 'fn': 29, 'auroc': 0.7726415094339623, 'auprc': 0.7544863871360068, 'eval_loss': 0.7337187620309683}
# {'mcc': 0.38288414528063747,
#  'tp': 66,
#  'tn': 73,
#  'fp': 33,
#  'fn': 29,
#  'auroc': 0.7726415094339623,
# ...

# %% [markdown]
# ###epoch=9

# %%
result_btc_9, model_btc_9_outputs, wrong_predictions_btc_9 = model_btc_9.eval_model(eval_df)
result_btc_9
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.3880167621212943, 'tp': 70, 'tn': 69, 'fp': 37, 'fn': 25, 'auroc': 0.7472691161866931, 'auprc': 0.7303378031567782, 'eval_loss': 1.0862764211801381}
# {'auprc': 0.7303378031567782,
#  'auroc': 0.7472691161866931,
#  'eval_loss': 1.0862764211801381,
#  'fn': 25,
# ...

# %% [markdown]
# ##BERT-large

# %% [markdown]
# ###epoch=3

# %%
result_btl, model_btl_outputs, wrong_predictions_btl = model_btl.eval_model(eval_df)
result_btl
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.24989929491345142, 'tp': 81, 'tn': 39, 'fp': 67, 'fn': 14, 'auroc': 0.6843098311817278, 'auprc': 0.6376875423799058, 'eval_loss': 0.6691721402681791}
# {'mcc': 0.24989929491345142,
#  'tp': 81,
#  'tn': 39,
#  'fp': 67,
#  'fn': 14,
#  'auroc': 0.6843098311817278,
# ...

# %%
prec = 81/(81+67)
reca = 81/95
print("Precision is " + str(prec) +" ,recall rate is " + str(reca))
# Out:
# Precision is 0.5472972972972973 ,recall rate is 0.8526315789473684

# %% [markdown]
# ###epoch=6

# %%
result_btl_6, model_btl_6_outputs, wrong_predictions_btl_6 = model_btl_6.eval_model(eval_df)
result_btl_6
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.5511663209756055, 'tp': 73, 'tn': 83, 'fp': 23, 'fn': 22, 'auroc': 0.7777060575968222, 'auprc': 0.7238292308920997, 'eval_loss': 0.7701204373286321}
# {'mcc': 0.5511663209756055,
#  'tp': 73,
#  'tn': 83,
#  'fp': 23,
#  'fn': 22,
#  'auroc': 0.7777060575968222,
# ...

# %% [markdown]
# ###epoch=9

# %%
result_btl_9, model_btl_9_outputs, wrong_predictions_btl_9 = model_btl_9.eval_model(eval_df)
result_btl_9
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.47706057596822243, 'tp': 74, 'tn': 74, 'fp': 32, 'fn': 21, 'auroc': 0.8194637537239324, 'auprc': 0.8002566419086112, 'eval_loss': 0.8530703737185552}
# {'mcc': 0.47706057596822243,
#  'tp': 74,
#  'tn': 74,
#  'fp': 32,
#  'fn': 21,
#  'auroc': 0.8194637537239324,
# ...

# %% [markdown]
# ##BERT-large-cased

# %% [markdown]
# ###epoch=3

# %%
result_btlc, model_btlc_outputs, wrong_predictions_btlc = model_btlc.eval_model(eval_df)
result_btlc
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.4096934013035956, 'tp': 72, 'tn': 69, 'fp': 37, 'fn': 23, 'auroc': 0.7338133068520356, 'auprc': 0.6921810424813707, 'eval_loss': 0.5996052668644831}
# {'mcc': 0.4096934013035956,
#  'tp': 72,
#  'tn': 69,
#  'fp': 37,
#  'fn': 23,
#  'auroc': 0.7338133068520356,
# ...

# %% [markdown]
# ###epoch=6

# %%
result_btlc_6, model_btlc_6_outputs, wrong_predictions_btlc_6 = model_btlc_6.eval_model(eval_df)
result_btlc_6
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.30222968666404443, 'tp': 68, 'tn': 62, 'fp': 44, 'fn': 27, 'auroc': 0.6966236345580933, 'auprc': 0.6544618635770758, 'eval_loss': 0.6798777213463416}
# {'mcc': 0.30222968666404443,
#  'tp': 68,
#  'tn': 62,
#  'fp': 44,
#  'fn': 27,
#  'auroc': 0.6966236345580933,
# ...

# %% [markdown]
# ###epoch=9

# %%
result_btlc_9, model_btlc_9_outputs, wrong_predictions_btlc_9 = model_btlc_9.eval_model(eval_df)
result_btlc_9
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.435658473121096, 'tp': 71, 'tn': 73, 'fp': 33, 'fn': 24, 'auroc': 0.8118669314796424, 'auprc': 0.7746104528385339, 'eval_loss': 1.161240055010869}
# {'mcc': 0.435658473121096,
#  'tp': 71,
#  'tn': 73,
#  'fp': 33,
#  'fn': 24,
#  'auroc': 0.8118669314796424,
# ...

# %% [markdown]
# ##ALBERT

# %% [markdown]
# ###epoch=3

# %%
result_abl, model_abl_outputs, wrong_predictions_abl = model_abl.eval_model(eval_df)
result_abl
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_albert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.022049762617815848, 'tp': 14, 'tn': 92, 'fp': 14, 'fn': 81, 'auroc': 0.5823237338629593, 'auprc': 0.5250732825464284, 'eval_loss': 0.6724601158728967}
# {'mcc': 0.022049762617815848,
#  'tp': 14,
#  'tn': 92,
#  'fp': 14,
#  'fn': 81,
# ...

# %%
prec = 63/(63+57)
reca = 59/95
print("Precision is " + str(prec) +" ,recall rate is " + str(reca))
# Out:
# Precision is 0.525 ,recall rate is 0.6210526315789474

# %% [markdown]
# ###epoch=6

# %%
result_abl_6, model_abl_6_outputs, wrong_predictions_abl_6 = model_abl_6.eval_model(eval_df)
result_abl_6
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_albert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.0018514654251398496, 'tp': 79, 'tn': 18, 'fp': 88, 'fn': 16, 'auroc': 0.5390268123138033, 'auprc': 0.5188328994044652, 'eval_loss': 0.70477294921875}
# {'auprc': 0.5188328994044652,
#  'auroc': 0.5390268123138033,
#  'eval_loss': 0.70477294921875,
#  'fn': 16,
# ...

# %% [markdown]
# ###epoch=9

# %%
result_abl_9, model_abl_9_outputs, wrong_predictions_abl_9 = model_abl_9.eval_model(eval_df)
result_abl_9
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_albert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.42796112534095127, 'tp': 72, 'tn': 71, 'fp': 35, 'fn': 23, 'auroc': 0.7404170804369414, 'auprc': 0.6816272753334183, 'eval_loss': 0.8090665523822491}
# {'auprc': 0.6816272753334183,
#  'auroc': 0.7404170804369414,
#  'eval_loss': 0.8090665523822491,
#  'fn': 23,
# ...

# %% [markdown]
# ##ALBERT-xxl

# %% [markdown]
# ###epoch=3

# %%
result_abxxl, model_abxxl_outputs, wrong_predictions_abxxl = model_abxxl.eval_model(eval_df)
result_abxxl
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_albert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': -0.016765907634615725, 'tp': 3, 'tn': 102, 'fp': 4, 'fn': 92, 'auroc': 0.523286991062562, 'auprc': 0.48151604054756797, 'eval_loss': 0.6956716684194711}
# {'mcc': -0.016765907634615725,
#  'tp': 3,
#  'tn': 102,
#  'fp': 4,
#  'fn': 92,
# ...

# %%
prec = 3/(3+3)
reca = 3/95
print("Precision is " + str(prec) +" ,recall rate is " + str(reca))
# Out:
# Precision is 0.5 ,recall rate is 0.031578947368421054

# %% [markdown]
# ###epoch=6

# %%
result_abxxl_6, model_abxxl_6_outputs, wrong_predictions_abxxl_6 = model_abxxl_6.eval_model(eval_df)
result_abxxl_6
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_albert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.2604593300796828, 'tp': 65, 'tn': 61, 'fp': 45, 'fn': 30, 'auroc': 0.6841112214498509, 'auprc': 0.6526570665946044, 'eval_loss': 0.699952272268442}
# {'mcc': 0.2604593300796828,
#  'tp': 65,
#  'tn': 61,
#  'fp': 45,
#  'fn': 30,
#  'auroc': 0.6841112214498509,
# ...

# %% [markdown]
# ###epoch=9

# %%
result_abxxl_9, model_abxxl_9_outputs, wrong_predictions_abxxl_9 = model_abxxl_9.eval_model(eval_df)
result_abxxl_9
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_albert_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.2404393203871336, 'tp': 64, 'tn': 60, 'fp': 46, 'fn': 31, 'auroc': 0.7041708043694141, 'auprc': 0.6498597128064442, 'eval_loss': 0.6312863276554987}
# {'mcc': 0.2404393203871336,
#  'tp': 64,
#  'tn': 60,
#  'fp': 46,
#  'fn': 31,
#  'auroc': 0.7041708043694141,
# ...

# %%
prec = 49/(49+21)
reca = 49/95
print("Precision is " + str(prec) +" ,recall rate is " + str(reca))
# Out:
# Precision is 0.7 ,recall rate is 0.5157894736842106

# %% [markdown]
# ##deberta_base

# %% [markdown]
# ###epoch=3

# %%
result_dbb, model_dbb_outputs, wrong_predictions_dbb = model_dbb.eval_model(eval_df)
result_dbb
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_deberta_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.14955253524077722, 'tp': 50, 'tn': 66, 'fp': 40, 'fn': 45, 'auroc': 0.5796425024826216, 'auprc': 0.6190568982563878, 'eval_loss': 0.6807807890268472}
# {'mcc': 0.14955253524077722,
#  'tp': 50,
#  'tn': 66,
#  'fp': 40,
#  'fn': 45,
# ...

# %%
prec = 14/(14+20)
reca = 14/95
print("Precision is " + str(prec) +" ,recall rate is " + str(reca))
# Out:
# Precision is 0.4117647058823529 ,recall rate is 0.14736842105263157

# %% [markdown]
# ###epoch=6

# %%
result_dbb_6, model_dbb_6_outputs, wrong_predictions_dbb_6 = model_dbb_6.eval_model(eval_df)
result_dbb_6
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_deberta_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.45379134533725063, 'tp': 76, 'tn': 69, 'fp': 37, 'fn': 19, 'auroc': 0.8186196623634557, 'auprc': 0.7852724477376986, 'eval_loss': 0.5836917494352047}
# {'mcc': 0.45379134533725063,
#  'tp': 76,
#  'tn': 69,
#  'fp': 37,
#  'fn': 19,
# ...

# %% [markdown]
# ###epoch=9

# %%
result_dbb_9, model_dbb_9_outputs, wrong_predictions_dbb_9 = model_dbb_9.eval_model(eval_df)
result_dbb_9
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_deberta_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.3805793882349782, 'tp': 71, 'tn': 67, 'fp': 39, 'fn': 24, 'auroc': 0.7903674280039722, 'auprc': 0.7773166038534343, 'eval_loss': 1.2255758832459553}
# {'mcc': 0.3805793882349782,
#  'tp': 71,
#  'tn': 67,
#  'fp': 39,
#  'fn': 24,
# ...

# %% [markdown]
# ##deberta_large

# %% [markdown]
# ###epoch=3

# %%
result_dbl_1, model_dbl_1_outputs, wrong_predictions_dbl_1 = model_dbl_1.eval_model(eval_df)
result_dbl_1
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_deberta_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.27893306144370916, 'tp': 70, 'tn': 57, 'fp': 49, 'fn': 25, 'auroc': 0.6763654419066534, 'auprc': 0.6183213424263561, 'eval_loss': 0.6609973632372342}
# {'mcc': 0.27893306144370916,
#  'tp': 70,
#  'tn': 57,
#  'fp': 49,
#  'fn': 25,
# ...

# %%
prec = 66/(66+52)
reca = 66/95
print("Precision is " + str(prec) +" ,recall rate is " + str(reca))
# Out:
# Precision is 0.559322033898305 ,recall rate is 0.6947368421052632

# %% [markdown]
# ###epoch=6

# %%
result_dbl_1_6, model_dbl_1_6_outputs, wrong_predictions_dbl_1_6 = model_dbl_1_6.eval_model(eval_df)
result_dbl_1_6
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_deberta_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.5405194930401755, 'tp': 71, 'tn': 84, 'fp': 22, 'fn': 24, 'auroc': 0.8335153922542204, 'auprc': 0.8009638628738421, 'eval_loss': 0.9047028800615897}
# {'mcc': 0.5405194930401755,
#  'tp': 71,
#  'tn': 84,
#  'fp': 22,
#  'fn': 24,
# ...

# %% [markdown]
# ###epoch=9

# %%
result_dbl_1_9, model_dbl_1_9_outputs, wrong_predictions_dbl_1_9 = model_dbl_1_9.eval_model(eval_df)
result_dbl_1_9
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/201 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_deberta_512_2_2
# Running Evaluation:   0%|          | 0/26 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.5807794851604705, 'tp': 81, 'tn': 77, 'fp': 29, 'fn': 14, 'auroc': 0.8226415094339623, 'auprc': 0.7721516383966883, 'eval_loss': 0.850684687996713}
# {'mcc': 0.5807794851604705,
#  'tp': 81,
#  'tn': 77,
#  'fp': 29,
#  'fn': 14,
#  'auroc': 0.8226415094339623,
# ...
